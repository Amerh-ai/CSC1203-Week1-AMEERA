# %%
#This program is for lab week 1

# %%
print("Welcome to Python Programming!")
# Out:
# Welcome to Python Programming!

# %%
#Printing student name and course name

# %%
name = "AMEERA Mohammed"
print(name)
# Out:
# AMEERA Mohammed

# %%
courseName = "Python"
print(courseName)
# Out:
# Python

# %%
student_name = "Alice"
print(student_name,type(student_name))
# Out:
# Alice <class 'str'>

# %%
age = 20
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
gpa = 3.75
print(gpa,type(gpa))
# Out:
# 3.75 <class 'float'>

# %%
subjects = ["Math", "Python", "Physics"]
print(subjects,type(subjects))
# Out:
# ['Math', 'Python', 'Physics'] <class 'list'>

# %%
student_info = {"id":101,"year":2}
print(student_info,type(student_info))
# Out:
# {'id': 101, 'year': 2} <class 'dict'>

# %%
skills = {"python","SQL"}
print(skills,type(skills))
# Out:
# {'SQL', 'python'} <class 'set'>

# %%
is_enrolled = True
print(is_enrolled,type(is_enrolled))
# Out:
# True <class 'bool'>

# %%
graduation_date = None
print(graduation_date,type(graduation_date))
# Out:
# None <class 'NoneType'>
